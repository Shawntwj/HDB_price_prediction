# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
from geopy.distance import geodesic as GD
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
#Read the dataset
#df = pd.read_csv("resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv")
#df2 = pd.read_csv('PreprocessedHDB.csv')

df = pd.read_csv("HDB Final GeoCode.csv")
PIE = pd.read_csv("PIE.csv")
MCE = pd.read_csv("MCE.csv")
KJE = pd.read_csv("KJE.csv")
BKE = pd.read_csv("BKE.csv")
SLE = pd.read_csv("SLE.csv")
KPE = pd.read_csv("KPE.csv")
TPE = pd.read_csv("TPE.csv")
CTE = pd.read_csv("CTE.csv")
ECP = pd.read_csv("ECP.csv")
AYE = pd.read_csv("AYE.csv")

hawker = pd.read_csv("Preprocessed Hawker Centre.csv")
hospital = pd.read_csv("Preprocessed Hospital.csv")
mrt = pd.read_csv("Preprocessed MRT.csv")
park = pd.read_csv("Preprocessed Parks.csv")
polyclinic = pd.read_csv("Preprocessed Polyclinic.csv")
prisch = pd.read_csv("Preprocessed Pri School.csv")
shoppingmall = pd.read_csv("Preprocessed Shopping Mall.csv")
supermarket = pd.read_csv("Preprocessed Supermarket.csv")

# %%
#df["Address"] =  "Singapore " + df.street_name.astype(str) + ' Block ' + df.block.astype(str)

# %%
#previously ran code to add lat long of google API values of all unique address to all rows, howerver, index match in excel instead due to speed of lookup

#df['lat'] = ""
#df['lng'] = ""

#for i in range(len(df)):
#    df["lat"][i] = df2[df2["Address"] == df["Address"][i]]["lat"].sum()
#    df["lng"][i] = df2[df2["Address"] == df["Address"][i]]["lng"].sum()
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_32264\662948860.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lat"][i] = df2[df2["Address"] == df["Address"][i]]["lat"].sum()
# C:\Users\pokem\AppData\Local\Temp\ipykernel_32264\662948860.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lng"][i] = df2[df2["Address"] == df["Address"][i]]["lng"].sum()

# %%
#df.to_csv("HDB Final GeoCode.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134516 entries, 0 to 134515
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           134516 non-null  int64
#  1   month                134516 non-null  object
#  2   town                 134516 non-null  object
#  3   flat_type            134516 non-null  object
#  4   block                134516 non-null  object
#  5   street_name          134516 non-null  object
#  6   storey_range         134516 non-null  object
#  7   floor_area_sqm       134516 non-null  float64
#  8   flat_model           134516 non-null  object
#  9   lease_commence_date  134516 non-null  int64
#  10  remaining_lease      134516 non-null  object
#  11  resale_price         134516 non-null  float64
#  12  lat                  134516 non-null  float64
#  13  lng                  134516 non-null  float64
#  14  Address              134516 non-null  object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 15.4+ MB

# %%
df['month']= pd.to_datetime(df['month'])
df["date"] = df["month"]

# %%
df['year'], df['month'] = df['date'].dt.year, df['date'].dt.month

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'month', 'town', 'flat_type', 'block', 'street_name',
#        'storey_range', 'floor_area_sqm', 'flat_model', 'lease_commence_date',
#        'remaining_lease', 'resale_price', 'lat', 'lng', 'Address', 'date',
#        'year'],
#       dtype='object')

# %%
df["Dist from Nearest Expressway"] = ""
df["Nearest Expressway"] = ""

df["Dist from Nearest Hawker Centre"] = ""
df["Nearest Hawker Centre"] = ""

df["Dist from Nearest Public Hospital"] = ""
df["Nearest Public Hospital"] = ""

df["Dist from Nearest MRT"] = ""
df["Nearest MRT"] = ""

df["Dist from Nearest Park"] = ""
df["Nearest Park"] = ""

df["Dist from Polyclinic"] = ""
df["Nearest Polyclinic"] = ""

df["Dist from Primary School"] = ""
df["Nearest Primary School"] = ""

df["Dist from Shopping Mall"] = ""
df["Nearest Shopping Mall"] = ""

df["Dist from Nearest Supermarket"] = ""
df["Nearest Supermarket"] = ""


for i in range(len(df)):
    dist1 = (df["lat"][i], df["lng"][i])
    ExpresswayMin=float('inf')
    
    hawkerMin=float('inf')
    hospitalMin=float('inf')
    mrtMin=float('inf')
    parkMin=float('inf')
    polyclinicMin=float('inf')
    prischMin=float('inf')
    shoppingmallMin=float('inf')
    supermarketMin=float('inf')

    #dist between nearest expressway
    for a in range(len(PIE)):
        dist2 = (PIE["lat"][a], PIE["lng"][a])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "PIE"
    
    for b in range(len(MCE)):
        dist2 = (MCE["lat"][b], MCE["lng"][b])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "MCE"
            
    for c in range(len(KJE)):
        dist2 = (KJE["lat"][c], KJE["lng"][c])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "KJE"
            
    for d in range(len(BKE)):
        dist2 = (BKE["lat"][d], BKE["lng"][d])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "BKE"
    
    for e in range(len(SLE)):
        dist2 = (SLE["lat"][e], SLE["lng"][e])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "SLE"
            
    for f in range(len(KPE)):
        dist2 = (KPE["lat"][f], KPE["lng"][f])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "KPE"
            
    for g in range(len(TPE)):
        dist2 = (TPE["lat"][g], TPE["lng"][g])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "TPE"
            
    for h in range(len(CTE)):
        dist2 = (CTE["lat"][h], CTE["lng"][h])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "CTE"
            
    for j in range(len(ECP)):
        dist2 = (ECP["lat"][j], ECP["lng"][j])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "ECP"
            
    for k in range(len(AYE)):
        dist2 = (AYE["lat"][k], AYE["lng"][k])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "AYE"
            
    for l in range(len(hawker)):
        dist2 = (hawker["lat"][l], hawker["lng"][l])
        if (GD(dist1,dist2).km < hawkerMin):
            hawkerMin = GD(dist1,dist2).km
            hawkerName = hawker["Name"][l]
    
    for m in range(len(hospital)):
        dist2 = (hospital["lat"][m], hospital["lng"][m])
        if (GD(dist1,dist2).km < hospitalMin):
            hospitalMin = GD(dist1,dist2).km
            hospitalName = hospital["Name"][m]
    
    for n in range(len(mrt)):
        dist2 = (mrt["lat"][n], mrt["lng"][n])
        if (GD(dist1,dist2).km < mrtMin):
            mrtMin = GD(dist1,dist2).km
            mrtName = mrt["Station name English "][n]
    
    for o in range(len(park)):
        dist2 = (park["lat"][o], park["lng"][o])
        if (GD(dist1,dist2).km < parkMin):
            parkMin = GD(dist1,dist2).km
            parkName = park["Name"][o]
    
    for p in range(len(polyclinic)):
        dist2 = (polyclinic["lat"][p], polyclinic["lng"][p])
        if (GD(dist1,dist2).km < polyclinicMin):
            polyclinicMin = GD(dist1,dist2).km
            polyclinicName = polyclinic["Name/Location"][p]
    
    for q in range(len(prisch)):
        dist2 = (prisch["lat"][q], prisch["lng"][q])
        if (GD(dist1,dist2).km < prischMin):
            prischMin = GD(dist1,dist2).km
            prischName = prisch["Name"][q]
    
    for r in range(len(shoppingmall)):
        dist2 = (shoppingmall["lat"][r], shoppingmall["lng"][r])
        if (GD(dist1,dist2).km < shoppingmallMin):
            shoppingmallMin = GD(dist1,dist2).km
            shoppingmallName = shoppingmall["Name"][r]
    
    for s in range(len(supermarket)):
        dist2 = (supermarket["lat"][s], supermarket["lng"][s])
        if (GD(dist1,dist2).km < supermarketMin):
            supermarketMin = GD(dist1,dist2).km
            supermarketName = supermarket["Lic Name"][s]

            
    df["Dist from Nearest Expressway"][i] = ExpresswayMin
    df["Nearest Expressway"][i] = ExpressWay
    
    df["Dist from Nearest Hawker Centre"][i] = hawkerMin
    df["Nearest Hawker Centre"][i] = hawkerName

    df["Dist from Nearest Public Hospital"][i] = hospitalMin
    df["Nearest Public Hospital"][i] = hospitalName

    df["Dist from Nearest MRT"][i] = mrtMin
    df["Nearest MRT"][i] = mrtName

    df["Dist from Nearest Park"][i] = parkMin
    df["Nearest Park"][i] = parkName

    df["Dist from Polyclinic"][i] = polyclinicMin
    df["Nearest Polyclinic"][i] = polyclinicName

    df["Dist from Primary School"][i] = prischMin
    df["Nearest Primary School"][i] = prischName

    df["Dist from Shopping Mall"][i] = shoppingmallMin
    df["Nearest Shopping Mall"][i] = shoppingmallName

    df["Dist from Nearest Supermarket"][i] = supermarketMin
    df["Nearest Supermarket"][i] = supermarketName
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest Expressway"][i] = ExpresswayMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Expressway"][i] = ExpressWay
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest Hawker Centre"][i] = hawkerMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Hawker Centre"][i] = hawkerName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest Public Hospital"][i] = hospitalMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Public Hospital"][i] = hospitalName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:161: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest MRT"][i] = mrtMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest MRT"][i] = mrtName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest Park"][i] = parkMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Park"][i] = parkName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Polyclinic"][i] = polyclinicMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Polyclinic"][i] = polyclinicName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Primary School"][i] = prischMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Primary School"][i] = prischName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Shopping Mall"][i] = shoppingmallMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Shopping Mall"][i] = shoppingmallName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest Supermarket"][i] = supermarketMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\4016169529.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Supermarket"][i] = supermarketName
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 29>()
#     133 for q in range(len(prisch)):
#     134     dist2 = (prisch["lat"][q], prisch["lng"][q])
# --> 135     if (GD(dist1,dist2).km < prischMin):
#     136         prischMin = GD(dist1,dist2).km
#     137         prischName = prisch["Name"][q]
#
# File ~\anaconda3\lib\site-packages\geopy\distance.py:522, in geodesic.__init__(self, *args, **kwargs)
#     520 self.set_ellipsoid(kwargs.pop('ellipsoid', 'WGS-84'))
#     521 major, minor, f = self.ELLIPSOID
# --> 522 super().__init__(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\geopy\distance.py:275, in Distance.__init__(self, *args, **kwargs)
#     273     kilometers += args[0]
#     274 elif len(args) > 1:
# --> 275     for a, b in util.pairwise(args):
#     276         kilometers += self.measure(a, b)
#     278 kilometers += units.kilometers(**kwargs)
#
# File ~\anaconda3\lib\site-packages\geopy\util.py:17, in pairwise(seq)
#      13 """
#      14 Pair an iterable, e.g., (1, 2, 3, 4) -> ((1, 2), (2, 3), (3, 4))
#      15 """
#      16 for i in range(0, len(seq) - 1):
# ---> 17     yield (seq[i], seq[i + 1])
#
# KeyboardInterrupt:

# %%
df.iloc[[91273,91274]]
# Out:
#        Unnamed: 0  month     town flat_type block   street_name storey_range  \
# 91273       91273      2  PUNGGOL    4 ROOM  166A  PUNGGOL CTRL     10 TO 12
# 91274       91274      2  PUNGGOL    4 ROOM  676A    PUNGGOL DR     10 TO 12
#
#        floor_area_sqm         flat_model  lease_commence_date  ...  \
# 91273            95.0  Premium Apartment                 2004  ...
# 91274            93.0  Premium Apartment                 2016  ...
#
#       Dist from Nearest Park  Nearest Park  Dist from Polyclinic  \
# 91273               1.022146  Punggol Park              2.407144
# 91274
#
#         Nearest Polyclinic Dist from Primary School    Nearest Primary School  \
# 91273  Sengkang Polyclinic                  0.36502  Greendale Primary School
# 91274
#
#        Dist from Shopping Mall Nearest Shopping Mall  \
# 91273                 0.286988         Punggol Plaza
# 91274
#
#       Dist from Nearest Supermarket              Nearest Supermarket
# 91273                      0.298883  NTUC FAIRPRICE CO-OPERATIVE LTD
# 91274
#
# [2 rows x 35 columns]

# %%
df["Dist from Nearest Expressway"] = ""
df["Nearest Expressway"] = ""

df["Dist from Nearest Hawker Centre"] = ""
df["Nearest Hawker Centre"] = ""

df["Dist from Nearest Public Hospital"] = ""
df["Nearest Public Hospital"] = ""

df["Dist from Nearest MRT"] = ""
df["Nearest MRT"] = ""

df["Dist from Nearest Park"] = ""
df["Nearest Park"] = ""

df["Dist from Polyclinic"] = ""
df["Nearest Polyclinic"] = ""

df["Dist from Primary School"] = ""
df["Nearest Primary School"] = ""

df["Dist from Shopping Mall"] = ""
df["Nearest Shopping Mall"] = ""

df["Dist from Nearest Supermarket"] = ""
df["Nearest Supermarket"] = ""


for i in range(91274, len(df)):
    dist1 = (df["lat"][i], df["lng"][i])
    ExpresswayMin=float('inf')
    
    hawkerMin=float('inf')
    hospitalMin=float('inf')
    mrtMin=float('inf')
    parkMin=float('inf')
    polyclinicMin=float('inf')
    prischMin=float('inf')
    shoppingmallMin=float('inf')
    supermarketMin=float('inf')

    #dist between nearest expressway
    for a in range(len(PIE)):
        dist2 = (PIE["lat"][a], PIE["lng"][a])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "PIE"
    
    for b in range(len(MCE)):
        dist2 = (MCE["lat"][b], MCE["lng"][b])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "MCE"
            
    for c in range(len(KJE)):
        dist2 = (KJE["lat"][c], KJE["lng"][c])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "KJE"
            
    for d in range(len(BKE)):
        dist2 = (BKE["lat"][d], BKE["lng"][d])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "BKE"
    
    for e in range(len(SLE)):
        dist2 = (SLE["lat"][e], SLE["lng"][e])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "SLE"
            
    for f in range(len(KPE)):
        dist2 = (KPE["lat"][f], KPE["lng"][f])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "KPE"
            
    for g in range(len(TPE)):
        dist2 = (TPE["lat"][g], TPE["lng"][g])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "TPE"
            
    for h in range(len(CTE)):
        dist2 = (CTE["lat"][h], CTE["lng"][h])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "CTE"
            
    for j in range(len(ECP)):
        dist2 = (ECP["lat"][j], ECP["lng"][j])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "ECP"
            
    for k in range(len(AYE)):
        dist2 = (AYE["lat"][k], AYE["lng"][k])
        if (GD(dist1,dist2).km < ExpresswayMin):
            ExpresswayMin = GD(dist1,dist2).km
            ExpressWay = "AYE"
            
    for l in range(len(hawker)):
        dist2 = (hawker["lat"][l], hawker["lng"][l])
        if (GD(dist1,dist2).km < hawkerMin):
            hawkerMin = GD(dist1,dist2).km
            hawkerName = hawker["Name"][l]
    
    for m in range(len(hospital)):
        dist2 = (hospital["lat"][m], hospital["lng"][m])
        if (GD(dist1,dist2).km < hospitalMin):
            hospitalMin = GD(dist1,dist2).km
            hospitalName = hospital["Name"][m]
    
    for n in range(len(mrt)):
        dist2 = (mrt["lat"][n], mrt["lng"][n])
        if (GD(dist1,dist2).km < mrtMin):
            mrtMin = GD(dist1,dist2).km
            mrtName = mrt["Station name English "][n]
    
    for o in range(len(park)):
        dist2 = (park["lat"][o], park["lng"][o])
        if (GD(dist1,dist2).km < parkMin):
            parkMin = GD(dist1,dist2).km
            parkName = park["Name"][o]
    
    for p in range(len(polyclinic)):
        dist2 = (polyclinic["lat"][p], polyclinic["lng"][p])
        if (GD(dist1,dist2).km < polyclinicMin):
            polyclinicMin = GD(dist1,dist2).km
            polyclinicName = polyclinic["Name/Location"][p]
    
    for q in range(len(prisch)):
        dist2 = (prisch["lat"][q], prisch["lng"][q])
        if (GD(dist1,dist2).km < prischMin):
            prischMin = GD(dist1,dist2).km
            prischName = prisch["Name"][q]
    
    for r in range(len(shoppingmall)):
        dist2 = (shoppingmall["lat"][r], shoppingmall["lng"][r])
        if (GD(dist1,dist2).km < shoppingmallMin):
            shoppingmallMin = GD(dist1,dist2).km
            shoppingmallName = shoppingmall["Name"][r]
    
    for s in range(len(supermarket)):
        dist2 = (supermarket["lat"][s], supermarket["lng"][s])
        if (GD(dist1,dist2).km < supermarketMin):
            supermarketMin = GD(dist1,dist2).km
            supermarketName = supermarket["Lic Name"][s]

            
    df["Dist from Nearest Expressway"][i] = ExpresswayMin
    df["Nearest Expressway"][i] = ExpressWay
    
    df["Dist from Nearest Hawker Centre"][i] = hawkerMin
    df["Nearest Hawker Centre"][i] = hawkerName

    df["Dist from Nearest Public Hospital"][i] = hospitalMin
    df["Nearest Public Hospital"][i] = hospitalName

    df["Dist from Nearest MRT"][i] = mrtMin
    df["Nearest MRT"][i] = mrtName

    df["Dist from Nearest Park"][i] = parkMin
    df["Nearest Park"][i] = parkName

    df["Dist from Polyclinic"][i] = polyclinicMin
    df["Nearest Polyclinic"][i] = polyclinicName

    df["Dist from Primary School"][i] = prischMin
    df["Nearest Primary School"][i] = prischName

    df["Dist from Shopping Mall"][i] = shoppingmallMin
    df["Nearest Shopping Mall"][i] = shoppingmallName

    df["Dist from Nearest Supermarket"][i] = supermarketMin
    df["Nearest Supermarket"][i] = supermarketName
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest Expressway"][i] = ExpresswayMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Expressway"][i] = ExpressWay
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest Hawker Centre"][i] = hawkerMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Hawker Centre"][i] = hawkerName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest Public Hospital"][i] = hospitalMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Public Hospital"][i] = hospitalName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:161: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest MRT"][i] = mrtMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest MRT"][i] = mrtName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest Park"][i] = parkMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Park"][i] = parkName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Polyclinic"][i] = polyclinicMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Polyclinic"][i] = polyclinicName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Primary School"][i] = prischMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Primary School"][i] = prischName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Shopping Mall"][i] = shoppingmallMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Shopping Mall"][i] = shoppingmallName
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dist from Nearest Supermarket"][i] = supermarketMin
# C:\Users\pokem\AppData\Local\Temp\ipykernel_25580\3782276319.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nearest Supermarket"][i] = supermarketName

# %%
df.head()
# Out:
#    Unnamed: 0  month        town flat_type block        street_name  \
# 0           0      1  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
# 1           1      1  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4
# 2           2      1  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5
# 3           3      1  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10
# 4           4      1  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5
#
#   storey_range  floor_area_sqm      flat_model  lease_commence_date  ...  \
# 0     10 TO 12            44.0        Improved                 1979  ...
# 1     01 TO 03            67.0  New Generation                 1978  ...
# 2     01 TO 03            67.0  New Generation                 1980  ...
# 3     04 TO 06            68.0  New Generation                 1980  ...
# 4     01 TO 03            67.0  New Generation                 1980  ...
#
#   Dist from Nearest Park  Nearest Park  Dist from Polyclinic  \
# 0
# 1
# 2
# 3
# 4
#
#    Nearest Polyclinic Dist from Primary School Nearest Primary School  \
# 0
# 1
# 2
# 3
# 4
#
#    Dist from Shopping Mall Nearest Shopping Mall  \
# 0
# 1
# 2
# 3
# 4
#
#   Dist from Nearest Supermarket Nearest Supermarket
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 35 columns]

# %%
df.to_csv("HDB Final.csv")
