# %%
import requests as requests
import pandas as pd
import json
import folium
from folium.plugins import MarkerCluster
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('HDB Final.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134516 entries, 0 to 134515
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   month                              134516 non-null  int64
#  1   town                               134516 non-null  object
#  2   flat_type                          134516 non-null  object
#  3   block                              134516 non-null  object
#  4   street_name                        134516 non-null  object
#  5   storey_range                       134516 non-null  object
#  6   floor_area_sqm                     134516 non-null  float64
#  7   flat_model                         134516 non-null  object
#  8   lease_commence_date                134516 non-null  int64
#  9   remaining_lease                    134516 non-null  object
#  10  resale_price                       134516 non-null  float64
# ...

# %%
sns.pairplot(df[["floor_area_sqm", "lease_commence_date", "resale_price", "Dist from Nearest Expressway", "Dist from Nearest Hawker Centre", 
                "Dist from Nearest Public Hospital", "Dist from Nearest MRT", "Dist from Nearest Park", "Dist from Polyclinic", 
                 "Dist from Primary School", "Dist from Shopping Mall", "Dist from Nearest Supermarket"
                ]])

# %%
plt.figure(figsize = (12,7))

ax = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
