# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
from geopy.distance import geodesic as GD
import seaborn as sns
from sklearn.linear_model import LinearRegression
import requests

# %%
hdb = pd.read_csv('PreprocessedHDB.csv')

hawker = pd.read_csv("Preprocessed Hawker Centre.csv")
hospital = pd.read_csv("Preprocessed Hospital.csv")
mrt = pd.read_csv("Preprocessed MRT.csv")
park = pd.read_csv("Preprocessed Parks.csv")
polyclinic = pd.read_csv("Preprocessed Polyclinic.csv")
prisch = pd.read_csv("Preprocessed Pri School.csv")
shoppingmall = pd.read_csv("Preprocessed Shopping Mall.csv")
supermarket = pd.read_csv("Preprocessed Supermarket.csv")

# %%
hdb = hdb[(hdb["lat"] == 1.352083) & (hdb["lng"] ==103.819836)]

# %%
hdb
# Out:
#       Unnamed: 0    month        town flat_type block        street_name  \
# 795          795  2021-04  QUEENSTOWN    2 ROOM   109      C'WEALTH CRES
# 1893        1893  2021-11  QUEENSTOWN    3 ROOM    92        C'WEALTH DR
# 2920        2920  2022-02  QUEENSTOWN    3 ROOM    88        C'WEALTH CL
# 3382        3382  2022-03  QUEENSTOWN    3 ROOM   101      C'WEALTH CRES
# 3778        3778  2022-04    CLEMENTI    4 ROOM   411  C'WEALTH AVE WEST
# 4481        4481  2022-05    CLEMENTI    4 ROOM   410  C'WEALTH AVE WEST
# 4713        4713  2022-05  QUEENSTOWN    3 ROOM    87        C'WEALTH CL
# 6845        6845  2022-07  QUEENSTOWN    3 ROOM    84        C'WEALTH CL
# 8508        8508  2022-08  QUEENSTOWN    2 ROOM    82        C'WEALTH CL
# 8509        8509  2022-08  QUEENSTOWN    3 ROOM    81        C'WEALTH CL
# 8544        8544  2022-08  QUEENSTOWN    5 ROOM    7A       C'WEALTH AVE
# 8545        8545  2022-08  QUEENSTOWN    5 ROOM     7       C'WEALTH AVE
#
# ...

# %%
hdb["Address"] = hdb['Address'].str.replace("C'WEALTH", 'Commonwealth')

# %%
hdb['Address']
# Out:
# 0         Singapore Commonwealth CRES Block 109
# 1            Singapore Commonwealth DR Block 92
# 2            Singapore Commonwealth CL Block 88
# 3         Singapore Commonwealth CRES Block 101
# 4     Singapore Commonwealth AVE WEST Block 411
# 5     Singapore Commonwealth AVE WEST Block 410
# 6            Singapore Commonwealth CL Block 87
# 7            Singapore Commonwealth CL Block 84
# 8            Singapore Commonwealth CL Block 82
# 9            Singapore Commonwealth CL Block 81
# 10          Singapore Commonwealth AVE Block 7A
# 11           Singapore Commonwealth AVE Block 7
# Name: Address, dtype: object

# %%
hdb = hdb.reset_index(drop=True)

# %%
geo_s ='https://maps.googleapis.com/maps/api/geocode/json'
hdb["lat"] = ""
hdb["lng"] = ""


for i in range(len(hdb)):
    param = {'address': hdb["Address"][i], 'key': ''}

    response = requests.get(geo_s, params=param)

    json_dict = response.json()

    hdb["lat"][i] = json_dict['results'][0]['geometry']['location']['lat']
    hdb["lng"][i] = json_dict['results'][0]['geometry']['location']['lng']
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\1502688037.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdb["lat"][i] = json_dict['results'][0]['geometry']['location']['lat']
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\1502688037.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdb["lng"][i] = json_dict['results'][0]['geometry']['location']['lng']

# %%
hdb
# Out:
#     Unnamed: 0    month        town flat_type block        street_name  \
# 0          795  2021-04  QUEENSTOWN    2 ROOM   109      C'WEALTH CRES
# 1         1893  2021-11  QUEENSTOWN    3 ROOM    92        C'WEALTH DR
# 2         2920  2022-02  QUEENSTOWN    3 ROOM    88        C'WEALTH CL
# 3         3382  2022-03  QUEENSTOWN    3 ROOM   101      C'WEALTH CRES
# 4         3778  2022-04    CLEMENTI    4 ROOM   411  C'WEALTH AVE WEST
# 5         4481  2022-05    CLEMENTI    4 ROOM   410  C'WEALTH AVE WEST
# 6         4713  2022-05  QUEENSTOWN    3 ROOM    87        C'WEALTH CL
# 7         6845  2022-07  QUEENSTOWN    3 ROOM    84        C'WEALTH CL
# 8         8508  2022-08  QUEENSTOWN    2 ROOM    82        C'WEALTH CL
# 9         8509  2022-08  QUEENSTOWN    3 ROOM    81        C'WEALTH CL
# 10        8544  2022-08  QUEENSTOWN    5 ROOM    7A       C'WEALTH AVE
# 11        8545  2022-08  QUEENSTOWN    5 ROOM     7       C'WEALTH AVE
#
# ...

# %%
hdb.to_csv("HDB_fixed.csv")

# %%
hawker = hawker[(hawker["lat"] == 1.352083)]
hospital = hospital[(hospital["lat"] == 1.352083)]
mrt = mrt[(mrt["lat"] == 1.352083)]
park = park[(park["lat"] == 1.352083) ]
polyclinic = polyclinic[(polyclinic["lat"] == 1.352083)]
prisch = prisch[(prisch["lat"] == 1.352083)]
shoppingmall = shoppingmall[(shoppingmall["lat"] == 1.352083)]
supermarket = supermarket[(supermarket["lat"] == 1.352083)]

# %%
hawker
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Addressstr, Addressblock, Address, lat, lng]
# Index: []

# %%
hospital
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Address, lat, lng]
# Index: []

# %%
park
# Out:
#      Unnamed: 0         Name                Address       lat         lng
# 288         288  Arthur Park  Singapore Arthur Park  1.352083  103.819836

# %%
polyclinic
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name/Location, Address, lat, lng]
# Index: []

# %%
supermarket
# Out:
#      Unnamed: 0                         Lic Name Blk House  \
# 27           27        JSJ CORPORATION PTE. LTD.       31A
# 71           71  SHENG SIONG SUPERMARKET PTE LTD         4
# 255         255  NTUC FAIRPRICE CO-OPERATIVE LTD        51
# 270         270  NTUC FAIRPRICE CO-OPERATIVE LTD       598
# 338         338                U STARS PTE. LTD.       810
#
#                    Str Name Unit No  Postcode           Address       lat  \
# 27   TANAH MERAH COAST ROAD       1    498720  Singapore 498720  1.352083
# 71      WOODLANDS STREET 12      61    738623  Singapore 738623  1.352083
# 255       TAMPINES AVENUE 4       1    528523  Singapore 528523  1.352083
# 270        YISHUN RING ROAD       1    768698  Singapore 768698  1.352083
# 338  CHOA CHU KANG AVENUE 7       1    680810  Singapore 680810  1.352083
#
#             lng
# 27   103.819836
# 71   103.819836
# 255  103.819836
# 270  103.819836
# 338  103.819836

# %%
shoppingmall
# Out:
#     Unnamed: 0             Name                    Address       lat  \
# 5            5   Bugis Junction   Singapore Bugis Junction  1.352083
# 14          14              Duo              Singapore Duo  1.352083
# 40          40             PoMo             Singapore PoMo  1.352083
# 46          46  The South Beach  Singapore The South Beach  1.352083
#
#            lng
# 5   103.819836
# 14  103.819836
# 40  103.819836
# 46  103.819836

# %%
prisch
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Address, lat, lng]
# Index: []

# %%
mrt
# Out:
#      Unnamed: 0 Alpha-numeric code(s) In operation Station name English   \
# 122         132                               DT17              Downtown
#
#              Opening Name(s) during planning stages Abbreviation  \
# 122  12/22/2013 0:00   Landmark / Central Boulevard          DTN
#
#        Location(s)                 Line Announcement date  \
# 122  Downtown Core  Downtown Line (DTL)         6/14/2005
#
#                     Address       lat         lng
# 122  Singapore Downtown MRT  1.352083  103.819836

# %%
#mrt, shoppingmall, supermarket, park with wrong geocoding

# %%
def geocode(df):
    geo_s ='https://maps.googleapis.com/maps/api/geocode/json'
    df["lat"] = ""
    df["lng"] = ""


    for i in range(len(df)):
        param = {'address': df["Address"][i], 'key': ''}

        response = requests.get(geo_s, params=param)

        json_dict = response.json()

        df["lat"][i] = json_dict['results'][0]['geometry']['location']['lat']
        df["lng"][i] = json_dict['results'][0]['geometry']['location']['lng']

# %%
mrt = mrt.reset_index(drop=True)
supermarket = supermarket.reset_index(drop=True)
shoppingmall = shoppingmall.reset_index(drop=True)
park = park.reset_index(drop=True)

# %%
mrt["Address"][0] = "Singapore Downtown MRT Station"
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\3030324827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrt["Address"][0] = "Singapore Downtown MRT Station"

# %%
geocode(mrt)
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\173992955.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lat"][i] = json_dict['results'][0]['geometry']['location']['lat']
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\173992955.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lng"][i] = json_dict['results'][0]['geometry']['location']['lng']

# %%
mrt
# Out:
#    Unnamed: 0 Alpha-numeric code(s) In operation Station name English   \
# 0         132                               DT17              Downtown
#
#            Opening Name(s) during planning stages Abbreviation    Location(s)  \
# 0  12/22/2013 0:00   Landmark / Central Boulevard          DTN  Downtown Core
#
#                   Line Announcement date                         Address  \
# 0  Downtown Line (DTL)         6/14/2005  Singapore Downtown MRT Station
#
#         lat         lng
# 0  1.279375  103.852747

# %%
mrt.to_csv("MRT_fixed.csv")

# %%
shoppingmall
# Out:
#    Unnamed: 0             Name                    Address       lat  \
# 0           5   Bugis Junction   Singapore Bugis Junction  1.352083
# 1          14              Duo              Singapore Duo  1.352083
# 2          40             PoMo             Singapore PoMo  1.352083
# 3          46  The South Beach  Singapore The South Beach  1.352083
#
#           lng
# 0  103.819836
# 1  103.819836
# 2  103.819836
# 3  103.819836

# %%
shoppingmall["Address"][0] = "200 Victoria Street, Singapore, Singapore"
shoppingmall["Address"][1] = "7 Fraser Street. Singapore 189356"
shoppingmall["Address"][2] = "1 Selegie Rd, Singapore 188306"
shoppingmall["Address"][3] = "38 Beach Rd, Singapore 189767"
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\2397216421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shoppingmall["Address"][0] = "200 Victoria Street, Singapore, Singapore"
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\2397216421.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shoppingmall["Address"][1] = "7 Fraser Street. Singapore 189356"
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\2397216421.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
geocode(shoppingmall)
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\173992955.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lat"][i] = json_dict['results'][0]['geometry']['location']['lat']
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\173992955.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lng"][i] = json_dict['results'][0]['geometry']['location']['lng']

# %%
shoppingmall
# Out:
#    Unnamed: 0             Name                                    Address  \
# 0           5   Bugis Junction  200 Victoria Street, Singapore, Singapore
# 1          14              Duo          7 Fraser Street. Singapore 189356
# 2          40             PoMo             1 Selegie Rd, Singapore 188306
# 3          46  The South Beach              38 Beach Rd, Singapore 189767
#
#         lat         lng
# 0   1.29886  103.855548
# 1  1.299738  103.857097
# 2  1.300541  103.849252
# 3  1.295654  103.856495

# %%
shoppingmall.to_csv("Shoppingmall_Fixed.csv")

# %%
supermarket
# Out:
#    Unnamed: 0                         Lic Name Blk House  \
# 0          27        JSJ CORPORATION PTE. LTD.       31A
# 1          71  SHENG SIONG SUPERMARKET PTE LTD         4
# 2         255  NTUC FAIRPRICE CO-OPERATIVE LTD        51
# 3         270  NTUC FAIRPRICE CO-OPERATIVE LTD       598
# 4         338                U STARS PTE. LTD.       810
#
#                  Str Name Unit No  Postcode           Address       lat  \
# 0  TANAH MERAH COAST ROAD       1    498720  Singapore 498720  1.352083
# 1     WOODLANDS STREET 12      61    738623  Singapore 738623  1.352083
# 2       TAMPINES AVENUE 4       1    528523  Singapore 528523  1.352083
# 3        YISHUN RING ROAD       1    768698  Singapore 768698  1.352083
# 4  CHOA CHU KANG AVENUE 7       1    680810  Singapore 680810  1.352083
#
#           lng
# 0  103.819836
# 1  103.819836
# 2  103.819836
# 3  103.819836
# 4  103.819836

# %%
supermarket["Address"] = supermarket["Str Name"] + " Blk " + supermarket["Blk House"]

# %%
geocode(supermarket)
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\173992955.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lat"][i] = json_dict['results'][0]['geometry']['location']['lat']
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\173992955.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lng"][i] = json_dict['results'][0]['geometry']['location']['lng']

# %%
supermarket
# Out:
#    Unnamed: 0                         Lic Name Blk House  \
# 0          27        JSJ CORPORATION PTE. LTD.       31A
# 1          71  SHENG SIONG SUPERMARKET PTE LTD         4
# 2         255  NTUC FAIRPRICE CO-OPERATIVE LTD        51
# 3         270  NTUC FAIRPRICE CO-OPERATIVE LTD       598
# 4         338                U STARS PTE. LTD.       810
#
#                  Str Name Unit No  Postcode                         Address  \
# 0  TANAH MERAH COAST ROAD       1    498720  TANAH MERAH COAST ROAD Blk 31A
# 1     WOODLANDS STREET 12      61    738623       WOODLANDS STREET 12 Blk 4
# 2       TAMPINES AVENUE 4       1    528523        TAMPINES AVENUE 4 Blk 51
# 3        YISHUN RING ROAD       1    768698        YISHUN RING ROAD Blk 598
# 4  CHOA CHU KANG AVENUE 7       1    680810  CHOA CHU KANG AVENUE 7 Blk 810
#
#         lat         lng
# 0  1.317263  103.990923
# 1  1.433489   103.77979
# 2  1.352773  103.940684
# 3   1.41833  103.841239
# 4  1.373813  103.746676

# %%
supermarket.to_csv("Supermarket_Fixed.csv")

# %%
park["Address"][0] = "103 BRANKSOME ROAD SINGAPORE 439624"
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\4142754040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   park["Address"][0] = "103 BRANKSOME ROAD SINGAPORE 439624"

# %%
geocode(park)
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\173992955.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lat"][i] = json_dict['results'][0]['geometry']['location']['lat']
# C:\Users\pokem\AppData\Local\Temp\ipykernel_9604\173992955.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lng"][i] = json_dict['results'][0]['geometry']['location']['lng']

# %%
park.to_csv("Park_Fixed.csv")
