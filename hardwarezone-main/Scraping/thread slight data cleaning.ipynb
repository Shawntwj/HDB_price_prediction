# %%
# word count and stop word removal from threads 
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))

# %%
import pandas as pd
import re
df = pd.read_csv("threads.csv",names = ['forum', 'thread', 'thread_link', 'date'])
count = 0 
sentence = ""
for string in df["thread"].tolist():

    word_tokens = word_tokenize(string)
    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
  
    filtered_sentence = []

    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)
    sentence += " ".join(filtered_sentence)

sentence
# Out:
# "Info Grants/Subsidies Available For First TimerUseful WebsitesProperty News !Notice : No Advertisement In The ForumDirectory : HDB , EC Condo DiscussionsHDB correspondence public newslettersHDB Resale Flat TIME-LINE Discussion[ [ Official Aug 2022 BTO ] ]Which Direction Will Property Prices Go ?The Gazania[ [ Official November 2022 BTO ] ]Moving Resale Flat BrokeLentor Modern GuocolandFree Advice/Discussion Bank Mortgage loanBuilding loft/mezzanine inside condoSBF May 2022Clementi Peaks & Clementi NorthArc - Feb 2017 BTOLooking cosmetic dentist smile makeover weddingOfficial May 2018 BTOAdvice Needed : Which Town Better Resale School DistanceFree advice/discussion buy/sell Resale flat ( Part 6 ) - Part 2[ Official ] November 2016 BTO - Punngol Matilda Sundeck / Trio Northshore / Waterway Sunrise 1[ [ Official May 2022 BTO ] ]The Landmark @ chin swee roadWhat happens buy resale HDB single scheme gets married ?[ Discussion ] landlords , long take find tenants room vacant ?Jadescape Qi
# ...

# %%
# Import package
import matplotlib.pyplot as plt
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");
    
# Import packagec
from wordcloud import WordCloud, STOPWORDS
# Generate word cloud
wordcloud = WordCloud(width= 3000, height = 2000, random_state=1, background_color='salmon', colormap='Pastel1', collocations=False, stopwords = STOPWORDS).generate(sentence)
# Plot
plot_cloud(wordcloud)

# %%
hdb_df = df[~df['thread'].str.contains("EC|ec|condo|Condo")]

# %%
sentence = ""
for string in hdb_df["thread"].tolist():
    word_tokens = word_tokenize(string)
    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
    filtered_sentence = []
    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)
    sentence += " ".join(filtered_sentence)
sentence
# Out:
# "Info Grants/Subsidies Available For First TimerUseful WebsitesProperty News !Notice : No Advertisement In The ForumHDB correspondence public newslettersHDB Resale Flat TIME-LINE Discussion[ [ Official Aug 2022 BTO ] ]The Gazania[ [ Official November 2022 BTO ] ]Moving Resale Flat BrokeLentor Modern GuocolandFree Advice/Discussion Bank Mortgage loanSBF May 2022Clementi Peaks & Clementi NorthArc - Feb 2017 BTOLooking cosmetic dentist smile makeover weddingOfficial May 2018 BTOAdvice Needed : Which Town Better Resale School DistanceFree advice/discussion buy/sell Resale flat ( Part 6 ) - Part 2[ [ Official May 2022 BTO ] ]The Landmark @ chin swee roadWhat happens buy resale HDB single scheme gets married ?[ Discussion ] landlords , long take find tenants room vacant ?Jadescape Qing JianRES COURSEThe Commodore The Watergardens CanberraCan stand water feature noises swimning pool ?[ [ Official February 2023 BTO ] ]More BTO Flats Set Aside First-TimersNoisy neighbour upstairsresale OTP no
# ...

# %%
# Generate word cloud
wordcloud = WordCloud(width= 3000, height = 2000, random_state=1, background_color='salmon', colormap='Pastel1', collocations=False, stopwords = STOPWORDS).generate(sentence)
# Plot
plot_cloud(wordcloud)

# %%
hdb_df.to_csv("hdb_threads.csv", encoding="utf-8-sig", index=False)

# %%
hdb_df
# Out:
#                            forum  \
# 0     HomeSeekers and HomeMakers
# 1     HomeSeekers and HomeMakers
# 2     HomeSeekers and HomeMakers
# 3     HomeSeekers and HomeMakers
# 5     HomeSeekers and HomeMakers
# ...                          ...
# 4119  HomeSeekers and HomeMakers
# 4120  HomeSeekers and HomeMakers
# 4122  HomeSeekers and HomeMakers
# 4123  HomeSeekers and HomeMakers
# 4124  HomeSeekers and HomeMakers
#
#                                                  thread  \
# 0     Info on Grants/Subsidies Available For First T...
# 1                                       Useful Websites
# 2                                        Property News!
# 3                 Notice: No Advertisement In The Forum
# 5              HDB correspondence on public newsletters
# ...                                                 ...
# 4119  Hle Loan amount if there is a hdb Loan outstan...
# 4120  Where to do tempered glass custom @ Neighbourh...
# ...
