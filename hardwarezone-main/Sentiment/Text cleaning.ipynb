# %%
import pandas as pd

# packages: flair
import flair

# packages: vader
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# packages: textblob
from textblob import TextBlob

import re

# NLTK
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet as wn
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shawnteo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/shawnteo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !pip3 install flair==0.6
# !pip3 install vaderSentiment
# !pip3 install textblob

# %%
df = pd.read_csv("posts.csv", names=["forum","thread_title","thread_link","username","userlink","member_status","date","text","town"])

df_assigned = df[["date","text","town"]]

df_assigned
# Out:
#                 date                                               text  \
# 0       Sep 12, 2021  runroadliao said:\nThe rats are probably more ...
# 1       Sep 12, 2021  Worry the day covid infects rats and mice if i...
# 2       Sep 12, 2021            The zehzeh jin brave be pest controller
# 3       Sep 11, 2021               Must be coming from nearby churches.
# 4       Sep 11, 2021  potatoes_are_fluffy said:\n\n\nClick to expand...
# ...              ...                                                ...
# 205333  Sep 20, 2010  otacon said:\nwill the land beside yishun 10 b...
# 205334  Sep 21, 2010  Think09 said:\nI think u misunderstand. DBSS i...
# 205335   Oct 4, 2010  Results are out\n\nSianz Q no. 774 ... out of ...
# 205336   Oct 4, 2010  I believe there will be drop out. Not to worry...
# 205337   Oct 4, 2010  Huat ah..\nfinally i got my dream location..\n...
#
#               town
# 0       ang mo kio
# 1       ang mo kio
# 2       ang mo kio
# 3       ang mo kio
# 4       ang mo kio
# ...            ...
# 205333      yishun
# 205334      yishun
# 205335      yishun
# 205336      yishun
# 205337      yishun
#
# [205338 rows x 3 columns]

# %%
# Remove non-English words

# remove punc 
df_assigned['clean_text']  = df_assigned['text'].map(lambda x: re.sub("[^A-Za-z0-9]+"," ", str(x)))
# lower case
df_assigned['clean_text']  = df_assigned['clean_text'].apply(lambda x: x.lower())
# replace digit 
# df_assigned['clean_text'] = df_assigned['clean_text'].str.replace('\d+', '')

# tokenize
df_assigned['clean_text']  = [word_tokenize(row) for row in df_assigned['clean_text']]


# remove stopwords
stop_words = stopwords.words('english')
new_stop_words = ['u','m','lol','condo','said','also']
stop_words.extend(new_stop_words)
def remove_stopwords(text):
    return [w for w in text if w not in stop_words]
df_assigned['clean_text']  = df_assigned['clean_text'].apply(lambda x: remove_stopwords(x))

df_assigned['join_clean_text']  = df_assigned['clean_text'].apply(lambda x: " ".join(x))
# take out posts containing these amenities
df_assigned
# Out:
# /var/folders/54/d_ts3l1x0slbw8z6xjtw2ldm0000gn/T/ipykernel_13625/655327413.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_assigned['clean_text']  = df_assigned['text'].map(lambda x: re.sub("[^A-Za-z0-9]+"," ", str(x)))
# /var/folders/54/d_ts3l1x0slbw8z6xjtw2ldm0000gn/T/ipykernel_13625/655327413.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_assigned['clean_text']  = df_assigned['clean_text'].apply(lambda x: x.lower())
# /var/folders/54/d_ts3l1x0slbw8z6xjtw2ldm0000gn/T/ipykernel_13625/655327413.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_assigned['clean_text'] = df_assigned['clean_text'].str.replace('\d+', '')
# /var/folders/54/d_ts3l1x0slbw8z6xjtw2ldm0000gn/T/ipykernel_13625/655327413.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_assigned['clean_text'] = df_assigned['clean_text'].str.replace('\d+', '')
# /var/folders/54/d_ts3l1x0slbw8z6xjtw2ldm0000gn/T/ipykernel_13625/655327413.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_assigned['clean_text']  = [word_tokenize(row) for row in df_assigned['clean_text']]
# /var/folders/54/d_ts3l1x0slbw8z6xjtw2ldm0000gn/T/ipykernel_13625/655327413.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_assigned['clean_text']  = df_assigned['clean_text'].apply(lambda x: remove_stopwords(x))
# /var/folders/54/d_ts3l1x0slbw8z6xjtw2ldm0000gn/T/ipykernel_13625/655327413.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_assigned['join_clean_text']  = df_assigned['clean_text'].apply(lambda x: " ".join(x))
#                 date                                               text  \
# 0       Sep 12, 2021  runroadliao said:\nThe rats are probably more ...
# 1       Sep 12, 2021  Worry the day covid infects rats and mice if i...
# 2       Sep 12, 2021            The zehzeh jin brave be pest controller
# 3       Sep 11, 2021               Must be coming from nearby churches.
# 4       Sep 11, 2021  potatoes_are_fluffy said:\n\n\nClick to expand...
# ...              ...                                                ...
# 205333  Sep 20, 2010  otacon said:\nwill the land beside yishun 10 b...
# 205334  Sep 21, 2010  Think09 said:\nI think u misunderstand. DBSS i...
# 205335   Oct 4, 2010  Results are out\n\nSianz Q no. 774 ... out of ...
# 205336   Oct 4, 2010  I believe there will be drop out. Not to worry...
# 205337   Oct 4, 2010  Huat ah..\nfinally i got my dream location..\n...
#
#               town                                         clean_text  \
# 0       ang mo kio  [runroadliao, rats, probably, active, pple, ru...
# 1       ang mo kio  [worry, day, covid, infects, rats, mice, adapt...
# 2       ang mo kio             [zehzeh, jin, brave, pest, controller]
# 3       ang mo kio                   [must, coming, nearby, churches]
# 4       ang mo kio  [potatoes, fluffy, click, expand, useless, new...
# ...            ...                                                ...
# 205333      yishun  [otacon, land, beside, yishun, developed, curr...
# 205334      yishun  [think, think, misunderstand, dbss, raise, sal...
# 205335      yishun  [results, sianz, q, units, rm, usually, much, ...
# 205336      yishun  [believe, drop, worry, another, bto, yishun, y...
# 205337      yishun  [huat, ah, finally, got, dream, location, q, n...
#
#                                           join_clean_text
# 0       runroadliao rats probably active pple running ...
# 1       worry day covid infects rats mice adapts jump ...
# 2                        zehzeh jin brave pest controller
# 3                             must coming nearby churches
# 4       potatoes fluffy click expand useless newbie pi...
# ...                                                   ...
# 205333  otacon land beside yishun developed current fl...
# 205334  think think misunderstand dbss raise salary ra...
# 205335  results sianz q units rm usually much percenta...
# 205336         believe drop worry another bto yishun year
# 205337  huat ah finally got dream location q number la...
#
# [205338 rows x 5 columns]

# %%
df_assigned.to_csv("cleaned_text.csv",index=False)

# %%
def vader_sentiment(df, cols_lst):
    sid_obj = SentimentIntensityAnalyzer()
    
    for col in cols_lst:
        compound = []
        
        for text in df[col].to_list():
            sentiment_dict = sid_obj.polarity_scores(text) # this produces a dictionary, keys: neg, neu, pos, compound
            
            # only interested in compound
            compound.append(sentiment_dict['compound'])
        
        if len(sentiment_cols) > 1:
            column_compound = col + '_compound'
            df[column_compound] = compound
    
    else:
        df['compound'] = compound
    
    return df


vader_sentiment(df_assigned,)

# %%
def sentiment_analysis(tweet):
    def getSubjectivity(text):
        return TextBlob(text).sentiment.subjectivity
  
    # Create a function to get the polarity
    def getPolarity(text):
        return TextBlob(text).sentiment.polarity

        #Create two new columns ‘Subjectivity’ & ‘Polarity’
        tweet[‘TextBlob_Subjectivity’] =    tweet[‘tweet’].apply(getSubjectivity)
        tweet [‘TextBlob_Polarity’] = tweet[‘tweet’].apply(getPolarity)
        
    def getAnalysis(score):
        if score < 0:
            return ‘Negative’
        elif score == 0:
            return ‘Neutral’
        else:
            return ‘Positive’
        tweet [‘TextBlob_Analysis’] = tweet  [‘TextBlob_Polarity’].apply(getAnalysis )
        return tweet
